# %%
import cv2
import matplotlib.pyplot as plt
from laplacian_blend import laplacian_blender

# %%
# Test Images
sun = cv2.imread("sun.jpg")
sun = cv2.cvtColor(sun, cv2.COLOR_BGR2RGB)
moon = cv2.imread("moon.jpg")
moon = cv2.cvtColor(moon, cv2.COLOR_BGR2RGB)

# %%
# Test ComputePyr()
numLevels = 6
blender = laplacian_blender(sun,moon,None)
gaussianPyramid, laplacianPyramid = blender.ComputePyr(sun,numLevels)

for i, img in enumerate(gaussianPyramid):
    # Display the image
    plt.figure(figsize=(5, 5))
    #plt.imshow(img)
    plt.imshow(img, cmap='gray') #use if image is grayscale
    plt.title(f"Gaussian Level: {i}")
    plt.axis('off')  # Turn off axes
    plt.show()

for i, img in enumerate(laplacianPyramid):
    # Display the image
    plt.figure(figsize=(5, 5))
    #plt.imshow(img)
    plt.imshow(img, cmap='gray') #use if image is grayscale
    plt.title(f"Laplacian Level: {i}")
    plt.axis('off')  # Turn off axes
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..254.677367549351].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..252.7140457080987].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..249.53412337309862].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..245.36842159524332].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..231.52446046929995].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..67.1352703284463].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..82.6470111437021].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..88.95904343593504].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..109.30324422005882].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..112.874544787079].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..231.52446046929995].
